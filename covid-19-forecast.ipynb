# %% [markdown]
# # Forecasting COVID-19 Cases

# %% [markdown]
# ## Loading and cleaning data

# %%
# !pip install sodapy
# !pip install nbconvert
# Out:
# Requirement already satisfied: sodapy in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (2.2.0)
# Requirement already satisfied: requests>=2.28.1 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from sodapy) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.28.1->sodapy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.28.1->sodapy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.28.1->sodapy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.28.1->sodapy) (2024.8.30)
# Requirement already satisfied: nbconvert in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (7.16.4)
# Requirement already satisfied: beautifulsoup4 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (6.1.0)
# Requirement already satisfied: defusedxml in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (3.1.4)
# Requirement already satisfied: jupyter-core>=4.7 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (5.7.2)
# Requirement already satisfied: jupyterlab-pygments in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (2.1.5)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (3.0.2)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (0.10.0)
# Requirement already satisfied: nbformat>=5.7 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (5.10.4)
# Requirement already satisfied: packaging in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (24.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (2.18.0)
# Requirement already satisfied: tinycss2 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (1.3.0)
# Requirement already satisfied: traitlets>=5.1 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbconvert) (5.14.3)
# Requirement already satisfied: six>=1.9.0 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->nbconvert) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from bleach!=5.0.0->nbconvert) (0.5.1)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core>=4.7->nbconvert) (4.3.6)
# Requirement already satisfied: pywin32>=300 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from jupyter-core>=4.7->nbconvert) (306)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbclient>=0.5.0->nbconvert) (8.6.3)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbformat>=5.7->nbconvert) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from nbformat>=5.7->nbconvert) (4.23.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4->nbconvert) (2.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert) (0.20.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=23.0 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (26.2.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\matth\appdata\local\programs\python\python312\lib\site-packages (from jupyter-client>=6.1.12->nbclient>=0.5.0->nbconvert) (6.4.1)

# %%
import numpy as np
import pandas as pd
import sodapy
from sodapy import Socrata
import matplotlib.pyplot as plt
from datetime import datetime

# %%
client = Socrata("data.cdc.gov", None)
results = client.get("7dk4-g6vg", limit = 100000)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
full_data=pd.DataFrame.from_records(results)
full_data.shape[0]
# Out:
# 12903

# %%
print(full_data.dtypes)
full_data.columns
# Out:
# week_ending_date                   object
# state                              object
# avg_adm_all_covid_confirmed        object
# pct_chg_avg_adm_all_covid          object
# total_adm_all_covid_confirmed      object
# total_adm_all_covid_confirmed_1    object
# sum_adm_all_covid_confirmed        object
# avg_total_patients                 object
# avg_percent_inpatient_beds         object
# abs_chg_avg_percent_inpatient      object
# avg_percent_staff_icu_beds         object
# abs_chg_avg_percent_staff          object
# dtype: object
# Index(['week_ending_date', 'state', 'avg_adm_all_covid_confirmed',
#        'pct_chg_avg_adm_all_covid', 'total_adm_all_covid_confirmed',
#        'total_adm_all_covid_confirmed_1', 'sum_adm_all_covid_confirmed',
#        'avg_total_patients', 'avg_percent_inpatient_beds',
#        'abs_chg_avg_percent_inpatient', 'avg_percent_staff_icu_beds',
#        'abs_chg_avg_percent_staff'],
#       dtype='object')

# %%
#renaming columns I'll be using
full_data=full_data.rename({
                 'state':'geo_location',
                 'avg_adm_all_covid_confirmed':'new_adm_7day_avg',
                 'total_adm_all_covid_confirmed':'new_adm_7day_total',
                 'total_adm_all_covid_confirmed_1':'new_adm_7day_total_per100k',
                 'avg_percent_inpatient_beds':'inpatient_bed_occ_7day_avg',
                 'avg_percent_staff_icu_beds':'icu_bed_occ_7day_avg'},axis=1)

# %%
#converting numerical variables to float64 instead of object
full_data=full_data.astype({
                 'new_adm_7day_avg':'float64',
                 'new_adm_7day_total':'float64',
                 'new_adm_7day_total_per100k':'float64',
                 'inpatient_bed_occ_7day_avg':'float64',
                 'icu_bed_occ_7day_avg':'float64'},errors = 'raise')[['week_ending_date','geo_location','new_adm_7day_total_per100k','inpatient_bed_occ_7day_avg','icu_bed_occ_7day_avg']]

# %%
full_data.head()
# Out:
#           week_ending_date geo_location  new_adm_7day_total_per100k  \
# 0  2023-09-23T00:00:00.000     Region 5                    5.184418
# 1  2023-09-30T00:00:00.000     Region 5                    5.007417
# 2  2023-10-07T00:00:00.000     Region 5                    4.796157
# 3  2023-10-14T00:00:00.000     Region 5                    4.341284
# 4  2023-10-21T00:00:00.000     Region 5                    4.910352
#
#    inpatient_bed_occ_7day_avg  icu_bed_occ_7day_avg
# 0                    1.870274              1.437423
# 1                    1.927454              1.557068
# 2                    1.763329              1.560869
# 3                    1.609312              1.262150
# 4                    1.769499              1.371294

# %% [markdown]
# ### Turning raw data into a useful timeseries
# I'm going to just use the "new_adm" column, since that's the metric that I'm concerned with (total new admissions per 100k for the previous 7 day period). I'll turn the week_ending column into the index, pivot on that, and drop the rest.

# %%
full_data['week']=pd.to_datetime(full_data['week_ending_date'])
full_data=full_data.set_index(['week']).drop(columns=['week_ending_date','inpatient_bed_occ_7day_avg','icu_bed_occ_7day_avg'])
full_data.head()
# Out:
#            geo_location  new_adm_7day_total_per100k
# week
# 2023-09-23     Region 5                    5.184418
# 2023-09-30     Region 5                    5.007417
# 2023-10-07     Region 5                    4.796157
# 2023-10-14     Region 5                    4.341284
# 2023-10-21     Region 5                    4.910352

# %%
case_data=full_data.pivot(columns='geo_location',values = 'new_adm_7day_total_per100k')
case_data.head()
# Out:
# geo_location        AK         AL         AR  AS         AZ         CA  \
# week
# 2020-08-08    3.827516  13.542218  14.878369 NaN  10.441401  11.849498
# 2020-08-15    3.007334  13.440243  13.652311 NaN   9.919331  10.358820
# 2020-08-22    4.237607  15.806053  14.083088 NaN   8.806497   8.374624
# 2020-08-29    4.237607  17.417250  11.332744 NaN   7.254026   7.324316
# 2020-09-05    4.784395  16.907378  10.868830 NaN   6.635785   6.744748
#
# geo_location        CO        CT         DC        DE  ...         TX  \
# week                                                   ...
# 2020-08-08    5.487315  2.832872  14.452730  0.718860  ...  17.861158
# 2020-08-15    4.445420  1.430460  14.736117  3.080829  ...  15.160774
# 2020-08-22    2.552643  2.159714  12.610716  4.826632  ...  13.163939
# 2020-08-29    2.378994  1.738990   9.776847  5.956269  ...  11.818920
# 2020-09-05    2.413724  2.187762  11.477168  6.777823  ...  11.111923
#
# geo_location       USA        UT        VA         VI        VT        WA  \
# week
# 2020-08-08    9.524743  3.992566  3.936492   0.939805  0.480778  2.495111
# 2020-08-15    8.996444  3.930182  4.944046   0.939805  0.801296  2.455714
# 2020-08-22    8.862412  2.776081  4.862036  15.976693  0.961555  2.127410
# 2020-08-29    8.491940  3.930182  4.639437   7.518444  0.961555  1.891031
# 2020-09-05    7.970267  4.335678  5.447823   3.759222  0.801296  2.534507
#
# geo_location        WI        WV         WY
# week
# 2020-08-08    8.810748  5.412502  12.094844
# 2020-08-15    8.295500  4.129126   6.911340
# 2020-08-22    7.608502  5.189306   6.392989
# 2020-08-29    7.333703  6.361085   6.392989
# 2020-09-05    6.784104  5.356703   7.256907
#
# [5 rows x 67 columns]

# %%
us_data=case_data['USA']

# %%
us_data.head()
# Out:
# week
# 2020-08-08    9.524743
# 2020-08-15    8.996444
# 2020-08-22    8.862412
# 2020-08-29    8.491940
# 2020-09-05    7.970267
# Name: USA, dtype: float64

# %%
us_data.tail()
# Out:
# week
# 2024-03-30    2.452645
# 2024-04-06    2.252349
# 2024-04-13    1.983681
# 2024-04-20    1.730676
# 2024-04-27    1.551464
# Name: USA, dtype: float64

# %% [markdown]
# #### Understanding our timeseries

# %%
fig, ax = plt.subplots(figsize=(16,8))
ax.plot(us_data)
fig.autofmt_xdate()

# %%
from statsmodels.tsa.seasonal import STL
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
diff_data= us_data.diff()[1:]
plt.plot(diff_data)

# %%
ad_fuller_result = adfuller(diff_data)
print(f'ADF Statistic: {ad_fuller_result[0]}')
print(f'p-value: {ad_fuller_result[1]}')
# Out:
# ADF Statistic: -5.943768658386367
# p-value: 2.2290576562940858e-07

# %%
plot_acf(diff_data, lags=50);

# %%
plot_pacf(diff_data, lags = 40, method = 'ywm');

# %%
from statsmodels.tsa.seasonal import STL

# %%
decomp = STL(us_data, period=52).fit()
fig, (ax1, ax2, ax3, ax4) = plt.subplots(nrows = 4, ncols =1, sharex = True, figsize = (10,8))
ax1.plot(decomp.observed)
ax1.set_ylabel('Observed')
ax2.plot(decomp.trend)
ax2.set_ylabel('Trend')
ax3.plot(decomp.seasonal)
ax3.set_ylabel('Seasonal')
ax4.plot(decomp.resid)
ax4.set_ylabel('Residuals')
fig.autofmt_xdate()
plt.tight_layout()

# %% [markdown]
# #### Format the data

# %%
us_data.tail(24)
# Out:
# week
# 2023-11-18     5.369735
# 2023-11-25     5.796229
# 2023-12-02     6.900718
# 2023-12-09     7.025112
# 2023-12-16     7.593771
# 2023-12-23     8.864219
# 2023-12-30    10.520198
# 2024-01-06    10.583751
# 2024-01-13     9.395229
# 2024-01-20     7.829307
# 2024-01-27     7.026317
# 2024-02-03     6.432959
# 2024-02-10     6.098631
# 2024-02-17     5.841710
# 2024-02-24     5.320339
# 2024-03-02     4.706198
# 2024-03-09     4.120070
# 2024-03-16     3.290574
# 2024-03-23     2.858959
# 2024-03-30     2.452645
# 2024-04-06     2.252349
# 2024-04-13     1.983681
# 2024-04-20     1.730676
# 2024-04-27     1.551464
# Name: USA, dtype: float64

# %%
train_stop='2024-02-24'
test_start='2024-03-02'
test_stop='2024-04-27'

# %%
train=us_data[:train_stop]
test=us_data[test_start:test_stop]
print(train.head())
print(train.tail())
print(test.head())
# Out:
# week
# 2020-08-08    9.524743
# 2020-08-15    8.996444
# 2020-08-22    8.862412
# 2020-08-29    8.491940
# 2020-09-05    7.970267
# Name: USA, dtype: float64
# week
# 2024-01-27    7.026317
# 2024-02-03    6.432959
# 2024-02-10    6.098631
# 2024-02-17    5.841710
# 2024-02-24    5.320339
# Name: USA, dtype: float64
# week
# 2024-03-02    4.706198
# 2024-03-09    4.120070
# 2024-03-16    3.290574
# 2024-03-23    2.858959
# 2024-03-30    2.452645
# Name: USA, dtype: float64

# %% [markdown]
# ### Model building and forecast

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
my_order = (3,1,3)
my_seasonal_order = (1,0,1,52)

# %% [markdown]
# Format the training set so it doesn't throw errors

# %%
train=train.reset_index(drop=True)
train
# Out:
# 0      9.524743
# 1      8.996444
# 2      8.862412
# 3      8.491940
# 4      7.970267
#          ...
# 181    7.026317
# 182    6.432959
# 183    6.098631
# 184    5.841710
# 185    5.320339
# Name: USA, Length: 186, dtype: float64

# %%
model=SARIMAX(train, order= my_order, seasonal_order=my_seasonal_order, simple_differencing = False)
SARIMA_model=model.fit(disp=False)
# Out:
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'

# %%
print(SARIMA_model.summary())
# Out:
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                                  USA   No. Observations:                  186
# Model:             SARIMAX(3, 1, 3)x(1, 0, [1], 52)   Log Likelihood                -255.617
# Date:                              Wed, 25 Sep 2024   AIC                            529.233
# Time:                                      22:55:06   BIC                            558.216
# Sample:                                           0   HQIC                           540.979
#                                               - 186
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.1895      0.169      7.058      0.000       0.859       1.520
# ar.L2         -0.0674      0.262     -0.257      0.797      -0.581       0.446
# ar.L3         -0.2421      0.122     -1.987      0.047      -0.481      -0.003
# ma.L1          0.0803      0.161      0.498      0.618      -0.235       0.396
# ma.L2         -0.5406      0.101     -5.349      0.000      -0.739      -0.343
# ma.L3         -0.4724      0.087     -5.427      0.000      -0.643      -0.302
# ar.S.L52       0.8611      0.200      4.297      0.000       0.468       1.254
# ma.S.L52      -0.6489      0.299     -2.167      0.030      -1.236      -0.062
# sigma2         0.8517      0.082     10.431      0.000       0.692       1.012
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):              3284.07
# Prob(Q):                              0.84   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.29   Skew:                             2.55
# Prob(H) (two-sided):                  0.00   Kurtosis:                        23.00
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
SARIMA_model.plot_diagnostics(figsize= (10,8));

# %% [markdown]
# #### Build rolling forecast function

# %%
def rolling_forecast(df: pd.DataFrame , train_len: int, horizon: int, window: int) -> list:

    total_len = train_len + horizon

    pred_model = []

    for i in range(train_len, total_len, window):
        model=SARIMAX(df[:i], order= my_order, seasonal_order=my_seasonal_order, simple_differencing = False)
        model_fit=model.fit(disp=False)
        predictions = model_fit.get_prediction(0,i + window - 1)
        oos_predictions=predictions.predicted_mean.iloc[-window:]
        pred_model.extend(oos_predictions)

    return pred_model

# %%
model_data=us_data.reset_index(drop=True)

# %% [markdown]
# Let's predict for the data we have and see how it matches

# %%
train_length = len(train)
horizon = len(test)
window = 1

predictions = rolling_forecast(model_data, train_length, horizon, window)
# Out:
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'

# %%
pred= pd.Series(predictions, index=test.index)
residuals = pd.Series(test - pred, index=test.index)
forecast_df=pd.DataFrame(test)
forecast_df['predictions']=pred
forecast_df['residuals']= residuals
forecast_df=forecast_df.rename(columns ={'USA':'actuals'})

# %%
plt.plot(forecast_df['actuals'], 'r-', forecast_df['predictions'],'-g')
# Out:
# [<matplotlib.lines.Line2D at 0x1d8b5d15700>,
#  <matplotlib.lines.Line2D at 0x1d8b5dc8410>]

# %%
MAE = np.mean(abs(residuals))
print('Mean Absolute Error: ', MAE)
# Out:
# Mean Absolute Error:  0.1752001622714126

# %%
print('Root Mean Squared Error: ', np.sqrt(np.mean(residuals**2)))
# Out:
# Root Mean Squared Error:  0.227022198752762

# %%
print('Mean Absolute Percent Error: ' , round(np.mean(abs(residuals/test)),4))
# Out:
# Mean Absolute Percent Error:  0.0608

# %%
future_weeks = 10

# %%
total_period= pd.date_range(min(us_data.index), periods = len(us_data)+future_weeks, freq = 'W')

# %%
train_length = len(train)
horizon = len(total_period) -  len(train)
window = 1

lt_predictions = rolling_forecast(model_data, train_length, horizon, window)
# Out:
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# C:\Users\matth\AppData\Local\Programs\Python\Python312\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'

# %%
lt_pred= pd.Series(lt_predictions, index=total_period[-(horizon):])

# %%
plt.figure(figsize=(16,8))
plt.plot(lt_pred, 'b-')
plt.plot(forecast_df['actuals'], '-r')

# %%
cases_per100k= np.max(lt_pred)*18.2*14

print('Peak Covid cases per 100k: ',cases_per100k)

n=70
prob_no_covid=(1-cases_per100k/100000)**n
print('Probability of visiting ',n,' people and not being exposed to covid: ',prob_no_covid)
# Out:
# Peak Covid cases per 100k:  1138.166350495191
# Probability of visiting  70  people and not being exposed to covid:  0.4487518916648084
