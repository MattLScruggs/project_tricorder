# %% [markdown]
# # Install dependencies and set up Socrata API

# %%
import numpy as np
import pandas as pd
import sodapy
from sodapy import Socrata
import matplotlib.pyplot as plt
from datetime import datetime
client = Socrata("data.cdc.gov", None) #add app token from CDC.gov profile
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %% [markdown]
# # COVID-19 Total 7-day Admissions per 100k

# %%
results = client.get("7dk4-g6vg", limit = 100000)

# %%
full_data=pd.DataFrame.from_records(results)
print(full_data.shape)
print(full_data.dtypes)
full_data.columns
# Out:
# (12903, 12)
# week_ending_date                   object
# state                              object
# avg_adm_all_covid_confirmed        object
# pct_chg_avg_adm_all_covid          object
# total_adm_all_covid_confirmed      object
# total_adm_all_covid_confirmed_1    object
# sum_adm_all_covid_confirmed        object
# avg_total_patients                 object
# avg_percent_inpatient_beds         object
# abs_chg_avg_percent_inpatient      object
# avg_percent_staff_icu_beds         object
# abs_chg_avg_percent_staff          object
# dtype: object
# Index(['week_ending_date', 'state', 'avg_adm_all_covid_confirmed',
#        'pct_chg_avg_adm_all_covid', 'total_adm_all_covid_confirmed',
#        'total_adm_all_covid_confirmed_1', 'sum_adm_all_covid_confirmed',
#        'avg_total_patients', 'avg_percent_inpatient_beds',
#        'abs_chg_avg_percent_inpatient', 'avg_percent_staff_icu_beds',
#        'abs_chg_avg_percent_staff'],
#       dtype='object')

# %%
full_data=full_data.rename({
                 'state':'geo_location',
                 'avg_adm_all_covid_confirmed':'new_adm_7day_avg',
                 'total_adm_all_covid_confirmed':'new_adm_7day_total',
                 'total_adm_all_covid_confirmed_1':'new_adm_7day_total_per100k',
                 'avg_percent_inpatient_beds':'inpatient_bed_occ_7day_avg',
                 'avg_percent_staff_icu_beds':'icu_bed_occ_7day_avg'},axis=1).astype({
                 'new_adm_7day_avg':'float64',
                 'new_adm_7day_total':'float64',
                 'new_adm_7day_total_per100k':'float64',
                 'inpatient_bed_occ_7day_avg':'float64',
                 'icu_bed_occ_7day_avg':'float64'},errors = 'raise')[['week_ending_date','geo_location','new_adm_7day_total_per100k','inpatient_bed_occ_7day_avg','icu_bed_occ_7day_avg']]

# %%
full_data['week']=pd.to_datetime(full_data['week_ending_date'])
full_data=full_data.set_index(['week']).drop(columns=['week_ending_date','inpatient_bed_occ_7day_avg','icu_bed_occ_7day_avg'])

# %%
case_data=full_data.pivot(columns='geo_location',values = 'new_adm_7day_total_per100k')

# %%
#case_data.to_csv('/drive/MyDrive/Documents/latest_covid_adm_data.csv')

# %%
us_data=case_data['USA']
us_data.name='New_COVID_7DayADM_rate'
us_data.head()
# Out:
# week
# 2020-08-08    9.524743
# 2020-08-15    8.996444
# 2020-08-22    8.862412
# 2020-08-29    8.491940
# 2020-09-05    7.970267
# Name: New_COVID_7DayADM_rate, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (16,8))
ax.plot(us_data)
fig.autofmt_xdate()

# %% [markdown]
# # NSSP ER Visits- COVID, Flu, RSV, Combined percentage of all ER Visits

# %%
er_visit_results=client.get('vutn-jzwm', limit = 20000)

# %%
full_data=pd.DataFrame.from_records(er_visit_results)
print(full_data.shape)
print(full_data.dtypes)
full_data.columns
# Out:
# (20000, 4)
# week_end          object
# pathogen          object
# geography         object
# percent_visits    object
# dtype: object
# Index(['week_end', 'pathogen', 'geography', 'percent_visits'], dtype='object')

# %%
full_data=full_data.astype({'percent_visits': 'float64'})

# %%
full_data['week']=pd.to_datetime(full_data['week_end'])

# %%
rate_data=full_data.loc[(full_data['geography']=='United States')].drop(columns = ['week_end','geography']).set_index(['week'])

# %%
er_adm_data= rate_data.pivot(columns = 'pathogen', values='percent_visits')
er_adm_data.head()
# Out:
# pathogen    COVID-19  Combined  Influenza  RSV
# week
# 2022-10-01       1.8       2.8        0.5  0.5
# 2022-10-08       1.7       2.9        0.7  0.6
# 2022-10-15       1.6       3.2        0.9  0.7
# 2022-10-22       1.6       3.7        1.3  0.8
# 2022-10-29       1.7       5.1        2.5  1.0

# %%
covid_er_data=pd.DataFrame(er_adm_data.iloc[:,0])
covid_er_data.rename(columns={'COVID-19':'ER_adm'},inplace=True)
covid_er_data.head()
# Out:
#             ER_adm
# week
# 2022-10-01     1.8
# 2022-10-08     1.7
# 2022-10-15     1.6
# 2022-10-22     1.6
# 2022-10-29     1.7

# %%
#er_adm_data.to_csv('/drive/MyDrive/Documents/latest_er_adm_data.csv')

# %%
fig, ax = plt.subplots(figsize = (16,8))
ax.plot(er_adm_data)
fig.autofmt_xdate()
plt.legend(['COVID-19','Combined','Influenza','RSV'], loc='upper right')

# %% [markdown]
# # Lab-Confirmed Hospitalizations of the Big Three (Rate per 100k)

# %%
lab_results = client.get("kvib-3txy", limit = 100000)

# %%
full_data=pd.DataFrame.from_records(lab_results)
print(full_data.shape)
print(full_data.dtypes)
full_data.columns
# Out:
# (43418, 12)
# surveillance_network    object
# season                  object
# mmwr_year               object
# mmwr_week               object
# age_group               object
# sex                     object
# race_ethnicity          object
# site                    object
# weekly_rate             object
# cumulative_rate         object
# _weekenddate            object
# type                    object
# dtype: object
# Index(['surveillance_network', 'season', 'mmwr_year', 'mmwr_week', 'age_group',
#        'sex', 'race_ethnicity', 'site', 'weekly_rate', 'cumulative_rate',
#        '_weekenddate', 'type'],
#       dtype='object')

# %%
full_data.head()
# Out:
#   surveillance_network   season mmwr_year mmwr_week age_group      sex  \
# 0             Combined  2023-24    2024.0      38.0   Overall  Overall
# 1             Combined  2023-24    2024.0      37.0   Overall  Overall
# 2             Combined  2023-24    2024.0      36.0   Overall  Overall
# 3             Combined  2023-24    2024.0      35.0   Overall  Overall
# 4             Combined  2023-24    2024.0      34.0   Overall  Overall
#
#   race_ethnicity  site        weekly_rate cumulative_rate  \
# 0        Overall  Utah                2.3           250.0
# 1        Overall  Utah                3.0           247.0
# 2        Overall  Utah  3.984298764938795           244.0
# 3        Overall  Utah  3.584298764938795           240.0
# 4        Overall  Utah                2.1           237.0
#
#           _weekenddate             type
# 0  2024-09-21 00:00:00  Unadjusted Rate
# 1  2024-09-14 00:00:00  Unadjusted Rate
# 2  2024-09-07 00:00:00  Unadjusted Rate
# 3  2024-08-31 00:00:00  Unadjusted Rate
# 4  2024-08-24 00:00:00  Unadjusted Rate

# %%
filtered_data = full_data.loc[(full_data['race_ethnicity'] == 'Overall') & (full_data['age_group'] == 'Overall') & (full_data['sex'] == 'Overall') & (full_data['site'] == 'Overall')][['surveillance_network','weekly_rate','_weekenddate']]

# %%
filtered_data= filtered_data.astype({'weekly_rate' : 'float64'})
filtered_data['week']=pd.to_datetime(filtered_data['_weekenddate'])

# %%
rate_data= filtered_data.drop(columns = '_weekenddate').set_index('week').pivot(columns = 'surveillance_network', values='weekly_rate')
rate_data.head()
# Out:
# surveillance_network  COVID-NET  Combined  FluSurv-NET  RSV-NET
# week
# 2018-10-06                  NaN  0.172305     0.072305      0.1
# 2018-10-13                  NaN  0.299850     0.099850      0.2
# 2018-10-20                  NaN  0.303293     0.103293      0.2
# 2018-10-27                  NaN  0.403293     0.103293      0.3
# 2018-11-03                  NaN  0.458383     0.158383      0.3

# %%
covid_rate_data=pd.DataFrame(rate_data.iloc[:,0])
#covid_rate_data.rename(columns={'COVID-19':'CTK_pos'},inplace=True)
covid_rate_data.head()
# Out:
#             COVID-NET
# week
# 2018-10-06        NaN
# 2018-10-13        NaN
# 2018-10-20        NaN
# 2018-10-27        NaN
# 2018-11-03        NaN

# %%
fig, ax = plt.subplots(figsize = (16,8))
ax.plot(rate_data)
fig.autofmt_xdate()
plt.legend(['COVID-NET','Combined','FluSurv-Net', 'RSV-NET'], loc='upper right')

# %% [markdown]
# # Percent of Positive Test Results

# %%
test_results = client.get("seuz-s2cv", limit = 100000)

# %%
full_data=pd.DataFrame.from_records(test_results)
print(full_data.shape)
print(full_data.dtypes)
full_data.columns
# Out:
# (312, 3)
# week_end                   object
# pathogen                   object
# percent_test_positivity    object
# dtype: object
# Index(['week_end', 'pathogen', 'percent_test_positivity'], dtype='object')

# %%
full_data= full_data.astype({'percent_test_positivity' : 'float64'})
full_data['week']=pd.to_datetime(full_data['week_end'])
test_data= full_data.drop(columns = 'week_end').set_index('week').pivot(columns = 'pathogen', values='percent_test_positivity')
test_data.head()
# Out:
# pathogen    COVID-19  Influenza   RSV
# week
# 2022-10-01       6.9        2.0  10.1
# 2022-10-08       6.9        2.7  12.4
# 2022-10-15       7.1        3.5  14.6
# 2022-10-22       6.8        5.4  16.5
# 2022-10-29       6.9        8.4  18.2

# %%
covid_test_data=pd.DataFrame(test_data.iloc[:,0])
covid_test_data.rename(columns={'COVID-19':'CTK_pos'},inplace=True)
covid_test_data.head()
# Out:
#             CTK_pos
# week
# 2022-10-01      6.9
# 2022-10-08      6.9
# 2022-10-15      7.1
# 2022-10-22      6.8
# 2022-10-29      6.9

# %%
fix, ax= plt.subplots(figsize = (16,8))
ax.plot(test_data)
fig.autofmt_xdate()
plt.legend(['COVID-19','Influenza', 'RSV'], loc='upper right')

# %% [markdown]
# # Total Weekly Cases

# %%
week_results = client.get("pwn4-m3yp", limit = 100000)

# %%
full_data=pd.DataFrame.from_records(week_results)
print(full_data.shape)
print(full_data.dtypes)
full_data.columns
# Out:
# (10380, 10)
# date_updated           object
# state                  object
# start_date             object
# end_date               object
# tot_cases              object
# new_cases              object
# tot_deaths             object
# new_deaths             object
# new_historic_cases     object
# new_historic_deaths    object
# dtype: object
# Index(['date_updated', 'state', 'start_date', 'end_date', 'tot_cases',
#        'new_cases', 'tot_deaths', 'new_deaths', 'new_historic_cases',
#        'new_historic_deaths'],
#       dtype='object')

# %%
full_data=full_data.astype({'new_cases' : 'float64'})
full_data['week']=pd.to_datetime(full_data['end_date'])
case_data= full_data.drop(columns = ['end_date','start_date']).set_index('week').pivot(columns = 'state', values='new_cases')
case_data['total']=case_data.sum(axis=1)

# %%
case_data=case_data.loc[:'2022-01-26']

# %%
case_data.shape
# Out:
# (106, 61)

# %%
total_case_data=pd.DataFrame(case_data.iloc[:,60])
total_case_data.rename(columns={'total':'confirmed_cases'},inplace=True)
total_case_data.head()
# Out:
#             confirmed_cases
# week
# 2020-01-22              6.0
# 2020-01-29              5.0
# 2020-02-05             12.0
# 2020-02-12             13.0
# 2020-02-19             16.0

# %%
fix, ax= plt.subplots(figsize = (16,8))
ax.plot(case_data)
fig.autofmt_xdate()

# %% [markdown]
# # Wastewater

# %%
week_results = client.get("g653-rqe2", limit = 300000)

# %%
full_data=pd.DataFrame.from_records(week_results)
print(full_data.shape)
print(full_data.dtypes)
full_data.columns
# Out:
# (222609, 4)
# key_plot_id      object
# date             object
# pcr_conc_lin     object
# normalization    object
# dtype: object
# Index(['key_plot_id', 'date', 'pcr_conc_lin', 'normalization'], dtype='object')

# %%
full_data['normalization'].unique()
# Out:
# array(['flow-population', 'microbial'], dtype=object)

# %%
full_data.head()
# Out:
#                                          key_plot_id        date  \
# 0  NWSS_mi_889_Before treatment plant_122_raw was...  2022-08-08
# 1  NWSS_mi_889_Before treatment plant_122_raw was...  2022-08-10
# 2  NWSS_mi_889_Before treatment plant_122_raw was...  2022-08-15
# 3  NWSS_mi_889_Before treatment plant_122_raw was...  2022-08-17
# 4  NWSS_mi_889_Before treatment plant_122_raw was...  2022-08-22
#
#          pcr_conc_lin    normalization
# 0  108205444.30383627  flow-population
# 1  146710661.49576557  flow-population
# 2  142685314.13387287  flow-population
# 3  117230139.89728022  flow-population
# 4   69845709.54037371  flow-population

# %%
full_data=full_data[(full_data['normalization'] == 'flow-population')]
full_data=full_data.astype({'pcr_conc_lin' : 'float64'})
full_data['log_concen']=np.log(full_data['pcr_conc_lin'])
full_data['week']=pd.to_datetime(full_data['date'])
water_data= full_data.drop(columns = ['normalization']).set_index('week').pivot(columns = 'key_plot_id', values='log_concen')

# %%
water_data.head()
# Out:
# key_plot_id  CDC_VERILY_ak_1490_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                                 NaN
# 2020-07-06                                                 NaN
# 2020-07-07                                                 NaN
# 2020-07-12                                                 NaN
# 2020-07-13                                                 NaN
#
# key_plot_id  CDC_VERILY_ak_1491_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                                 NaN
# 2020-07-06                                                 NaN
# 2020-07-07                                                 NaN
# 2020-07-12                                                 NaN
# 2020-07-13                                                 NaN
#
# key_plot_id  CDC_VERILY_ak_2633_Treatment plant_post grit removal  \
# week
# 2020-07-05                                                 NaN
# 2020-07-06                                                 NaN
# 2020-07-07                                                 NaN
# 2020-07-12                                                 NaN
# 2020-07-13                                                 NaN
#
# key_plot_id  CDC_VERILY_ak_2844_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                                 NaN
# 2020-07-06                                                 NaN
# 2020-07-07                                                 NaN
# 2020-07-12                                                 NaN
# 2020-07-13                                                 NaN
#
# key_plot_id  CDC_VERILY_al_2510_Treatment plant_post grit removal  \
# week
# 2020-07-05                                                 NaN
# 2020-07-06                                                 NaN
# 2020-07-07                                                 NaN
# 2020-07-12                                                 NaN
# 2020-07-13                                                 NaN
#
# key_plot_id  CDC_VERILY_al_2629_Treatment plant_post grit removal  \
# week
# 2020-07-05                                                 NaN
# 2020-07-06                                                 NaN
# 2020-07-07                                                 NaN
# 2020-07-12                                                 NaN
# 2020-07-13                                                 NaN
#
# key_plot_id  CDC_VERILY_ar_1542_Treatment plant_post grit removal  \
# week
# 2020-07-05                                                 NaN
# 2020-07-06                                                 NaN
# 2020-07-07                                                 NaN
# 2020-07-12                                                 NaN
# 2020-07-13                                                 NaN
#
# key_plot_id  CDC_VERILY_ar_1543_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                                 NaN
# 2020-07-06                                                 NaN
# 2020-07-07                                                 NaN
# 2020-07-12                                                 NaN
# 2020-07-13                                                 NaN
#
# key_plot_id  CDC_VERILY_ar_1546_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                                 NaN
# 2020-07-06                                                 NaN
# 2020-07-07                                                 NaN
# 2020-07-12                                                 NaN
# 2020-07-13                                                 NaN
#
# key_plot_id  CDC_VERILY_ar_2507_Treatment plant_raw wastewater  ...  \
# week                                                            ...
# 2020-07-05                                                 NaN  ...
# 2020-07-06                                                 NaN  ...
# 2020-07-07                                                 NaN  ...
# 2020-07-12                                                 NaN  ...
# 2020-07-13                                                 NaN  ...
#
# key_plot_id  NWSS_wv_91_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                         NaN
# 2020-07-06                                         NaN
# 2020-07-07                                         NaN
# 2020-07-12                                         NaN
# 2020-07-13                                         NaN
#
# key_plot_id  NWSS_wv_961_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                          NaN
# 2020-07-06                                          NaN
# 2020-07-07                                          NaN
# 2020-07-12                                          NaN
# 2020-07-13                                          NaN
#
# key_plot_id  NWSS_wy_2625_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                           NaN
# 2020-07-06                                           NaN
# 2020-07-07                                           NaN
# 2020-07-12                                           NaN
# 2020-07-13                                           NaN
#
# key_plot_id  NWSS_wy_2626_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                           NaN
# 2020-07-06                                           NaN
# 2020-07-07                                           NaN
# 2020-07-12                                           NaN
# 2020-07-13                                           NaN
#
# key_plot_id  NWSS_wy_2627_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                           NaN
# 2020-07-06                                           NaN
# 2020-07-07                                           NaN
# 2020-07-12                                           NaN
# 2020-07-13                                           NaN
#
# key_plot_id  NWSS_wy_2628_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                           NaN
# 2020-07-06                                           NaN
# 2020-07-07                                           NaN
# 2020-07-12                                           NaN
# 2020-07-13                                           NaN
#
# key_plot_id  NWSS_wy_2721_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                           NaN
# 2020-07-06                                           NaN
# 2020-07-07                                           NaN
# 2020-07-12                                           NaN
# 2020-07-13                                           NaN
#
# key_plot_id  NWSS_wy_2732_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                           NaN
# 2020-07-06                                           NaN
# 2020-07-07                                           NaN
# 2020-07-12                                           NaN
# 2020-07-13                                           NaN
#
# key_plot_id  NWSS_wy_2740_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                           NaN
# 2020-07-06                                           NaN
# 2020-07-07                                           NaN
# 2020-07-12                                           NaN
# 2020-07-13                                           NaN
#
# key_plot_id  NWSS_wy_2855_Treatment plant_raw wastewater
# week
# 2020-07-05                                           NaN
# 2020-07-06                                           NaN
# 2020-07-07                                           NaN
# 2020-07-12                                           NaN
# 2020-07-13                                           NaN
#
# [5 rows x 1255 columns]

# %%
na_counts=water_data.isna().sum()
const_sites=list(na_counts.nsmallest(10).index)
print(na_counts.nsmallest(10))
# Out:
# key_plot_id
# NWSS_mi_799_Treatment plant_post grit removal    390
# NWSS_wv_2558_Treatment plant_raw wastewater      393
# NWSS_mi_762_Treatment plant_post grit removal    424
# NWSS_mi_757_Treatment plant_post grit removal    516
# NWSS_nv_554_Treatment plant_90_raw wastewater    522
# NWSS_mi_761_Treatment plant_post grit removal    532
# NWSS_mi_800_Treatment plant_raw wastewater       551
# NWSS_wi_231_Treatment plant_raw wastewater       647
# NWSS_wv_2562_Treatment plant_raw wastewater      797
# NWSS_wv_2553_Treatment plant_raw wastewater      810
# dtype: int64

# %%
water_data_c=water_data[water_data.columns.intersection(const_sites)]
water_data_c.head()
# Out:
# key_plot_id  NWSS_mi_757_Treatment plant_post grit removal  \
# week
# 2020-07-05                                             NaN
# 2020-07-06                                             NaN
# 2020-07-07                                             NaN
# 2020-07-12                                             NaN
# 2020-07-13                                             NaN
#
# key_plot_id  NWSS_mi_761_Treatment plant_post grit removal  \
# week
# 2020-07-05                                             NaN
# 2020-07-06                                             NaN
# 2020-07-07                                             NaN
# 2020-07-12                                             NaN
# 2020-07-13                                             NaN
#
# key_plot_id  NWSS_mi_762_Treatment plant_post grit removal  \
# week
# 2020-07-05                                             NaN
# 2020-07-06                                             NaN
# 2020-07-07                                             NaN
# 2020-07-12                                             NaN
# 2020-07-13                                             NaN
#
# key_plot_id  NWSS_mi_799_Treatment plant_post grit removal  \
# week
# 2020-07-05                                             NaN
# 2020-07-06                                             NaN
# 2020-07-07                                             NaN
# 2020-07-12                                             NaN
# 2020-07-13                                             NaN
#
# key_plot_id  NWSS_mi_800_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                          NaN
# 2020-07-06                                          NaN
# 2020-07-07                                          NaN
# 2020-07-12                                          NaN
# 2020-07-13                                          NaN
#
# key_plot_id  NWSS_nv_554_Treatment plant_90_raw wastewater  \
# week
# 2020-07-05                                             NaN
# 2020-07-06                                             NaN
# 2020-07-07                                             NaN
# 2020-07-12                                             NaN
# 2020-07-13                                             NaN
#
# key_plot_id  NWSS_wi_231_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                          NaN
# 2020-07-06                                          NaN
# 2020-07-07                                          NaN
# 2020-07-12                                          NaN
# 2020-07-13                                          NaN
#
# key_plot_id  NWSS_wv_2553_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                           NaN
# 2020-07-06                                           NaN
# 2020-07-07                                           NaN
# 2020-07-12                                           NaN
# 2020-07-13                                           NaN
#
# key_plot_id  NWSS_wv_2558_Treatment plant_raw wastewater  \
# week
# 2020-07-05                                           NaN
# 2020-07-06                                           NaN
# 2020-07-07                                           NaN
# 2020-07-12                                           NaN
# 2020-07-13                                           NaN
#
# key_plot_id  NWSS_wv_2562_Treatment plant_raw wastewater
# week
# 2020-07-05                                           NaN
# 2020-07-06                                           NaN
# 2020-07-07                                           NaN
# 2020-07-12                                           NaN
# 2020-07-13                                           NaN

# %%
fix, ax= plt.subplots(figsize = (16,8))
ax.plot(water_data_c)
fig.autofmt_xdate()

# %% [markdown]
# # Join tables together into dataset

# %%
agg_data= water_data_c.merge(total_case_data, on='week', how = 'outer').merge(covid_test_data, on='week',how='outer')\
.merge(covid_rate_data, on='week',how='outer').merge(covid_er_data, on='week', how='outer').merge(us_data, on='week', how='outer').dropna(how='all')
print(agg_data.shape)
agg_data.head()
# Out:
# (1456, 15)
#             NWSS_mi_757_Treatment plant_post grit removal  \
# week
# 2020-01-22                                            NaN
# 2020-01-29                                            NaN
# 2020-02-05                                            NaN
# 2020-02-12                                            NaN
# 2020-02-19                                            NaN
#
#             NWSS_mi_761_Treatment plant_post grit removal  \
# week
# 2020-01-22                                            NaN
# 2020-01-29                                            NaN
# 2020-02-05                                            NaN
# 2020-02-12                                            NaN
# 2020-02-19                                            NaN
#
#             NWSS_mi_762_Treatment plant_post grit removal  \
# week
# 2020-01-22                                            NaN
# 2020-01-29                                            NaN
# 2020-02-05                                            NaN
# 2020-02-12                                            NaN
# 2020-02-19                                            NaN
#
#             NWSS_mi_799_Treatment plant_post grit removal  \
# week
# 2020-01-22                                            NaN
# 2020-01-29                                            NaN
# 2020-02-05                                            NaN
# 2020-02-12                                            NaN
# 2020-02-19                                            NaN
#
#             NWSS_mi_800_Treatment plant_raw wastewater  \
# week
# 2020-01-22                                         NaN
# 2020-01-29                                         NaN
# 2020-02-05                                         NaN
# 2020-02-12                                         NaN
# 2020-02-19                                         NaN
#
#             NWSS_nv_554_Treatment plant_90_raw wastewater  \
# week
# 2020-01-22                                            NaN
# 2020-01-29                                            NaN
# 2020-02-05                                            NaN
# 2020-02-12                                            NaN
# 2020-02-19                                            NaN
#
#             NWSS_wi_231_Treatment plant_raw wastewater  \
# week
# 2020-01-22                                         NaN
# 2020-01-29                                         NaN
# 2020-02-05                                         NaN
# 2020-02-12                                         NaN
# 2020-02-19                                         NaN
#
#             NWSS_wv_2553_Treatment plant_raw wastewater  \
# week
# 2020-01-22                                          NaN
# 2020-01-29                                          NaN
# 2020-02-05                                          NaN
# 2020-02-12                                          NaN
# 2020-02-19                                          NaN
#
#             NWSS_wv_2558_Treatment plant_raw wastewater  \
# week
# 2020-01-22                                          NaN
# 2020-01-29                                          NaN
# 2020-02-05                                          NaN
# 2020-02-12                                          NaN
# 2020-02-19                                          NaN
#
#             NWSS_wv_2562_Treatment plant_raw wastewater  confirmed_cases  \
# week
# 2020-01-22                                          NaN              6.0
# 2020-01-29                                          NaN              5.0
# 2020-02-05                                          NaN             12.0
# 2020-02-12                                          NaN             13.0
# 2020-02-19                                          NaN             16.0
#
#             CTK_pos  COVID-NET  ER_adm  New_COVID_7DayADM_rate
# week
# 2020-01-22      NaN        NaN     NaN                     NaN
# 2020-01-29      NaN        NaN     NaN                     NaN
# 2020-02-05      NaN        NaN     NaN                     NaN
# 2020-02-12      NaN        NaN     NaN                     NaN
# 2020-02-19      NaN        NaN     NaN                     NaN

# %%
agg_data.corr()
# Out:
#                                                NWSS_mi_757_Treatment plant_post grit removal  \
# NWSS_mi_757_Treatment plant_post grit removal                                       1.000000
# NWSS_mi_761_Treatment plant_post grit removal                                       0.694003
# NWSS_mi_762_Treatment plant_post grit removal                                       0.695035
# NWSS_mi_799_Treatment plant_post grit removal                                       0.608631
# NWSS_mi_800_Treatment plant_raw wastewater                                          0.641268
# NWSS_nv_554_Treatment plant_90_raw wastewater                                       0.043701
# NWSS_wi_231_Treatment plant_raw wastewater                                          0.611308
# NWSS_wv_2553_Treatment plant_raw wastewater                                         0.402240
# NWSS_wv_2558_Treatment plant_raw wastewater                                         0.214886
# NWSS_wv_2562_Treatment plant_raw wastewater                                         0.455062
# confirmed_cases                                                                     0.350145
# CTK_pos                                                                             0.421533
# COVID-NET                                                                           0.595346
# ER_adm                                                                              0.690394
# New_COVID_7DayADM_rate                                                              0.460653
#
#                                                NWSS_mi_761_Treatment plant_post grit removal  \
# NWSS_mi_757_Treatment plant_post grit removal                                       0.694003
# NWSS_mi_761_Treatment plant_post grit removal                                       1.000000
# NWSS_mi_762_Treatment plant_post grit removal                                       0.645992
# NWSS_mi_799_Treatment plant_post grit removal                                       0.617989
# NWSS_mi_800_Treatment plant_raw wastewater                                          0.589465
# NWSS_nv_554_Treatment plant_90_raw wastewater                                       0.215758
# NWSS_wi_231_Treatment plant_raw wastewater                                          0.499189
# NWSS_wv_2553_Treatment plant_raw wastewater                                         0.483040
# NWSS_wv_2558_Treatment plant_raw wastewater                                         0.367278
# NWSS_wv_2562_Treatment plant_raw wastewater                                         0.414128
# confirmed_cases                                                                     0.847974
# CTK_pos                                                                             0.428220
# COVID-NET                                                                           0.515036
# ER_adm                                                                              0.606376
# New_COVID_7DayADM_rate                                                              0.433305
#
#                                                NWSS_mi_762_Treatment plant_post grit removal  \
# NWSS_mi_757_Treatment plant_post grit removal                                       0.695035
# NWSS_mi_761_Treatment plant_post grit removal                                       0.645992
# NWSS_mi_762_Treatment plant_post grit removal                                       1.000000
# NWSS_mi_799_Treatment plant_post grit removal                                       0.665164
# NWSS_mi_800_Treatment plant_raw wastewater                                          0.628532
# NWSS_nv_554_Treatment plant_90_raw wastewater                                       0.175970
# NWSS_wi_231_Treatment plant_raw wastewater                                          0.528293
# NWSS_wv_2553_Treatment plant_raw wastewater                                         0.313517
# NWSS_wv_2558_Treatment plant_raw wastewater                                         0.227151
# NWSS_wv_2562_Treatment plant_raw wastewater                                         0.315206
# confirmed_cases                                                                     0.411237
# CTK_pos                                                                             0.335618
# COVID-NET                                                                           0.482945
# ER_adm                                                                              0.589005
# New_COVID_7DayADM_rate                                                              0.286518
#
#                                                NWSS_mi_799_Treatment plant_post grit removal  \
# NWSS_mi_757_Treatment plant_post grit removal                                       0.608631
# NWSS_mi_761_Treatment plant_post grit removal                                       0.617989
# NWSS_mi_762_Treatment plant_post grit removal                                       0.665164
# NWSS_mi_799_Treatment plant_post grit removal                                       1.000000
# NWSS_mi_800_Treatment plant_raw wastewater                                          0.582934
# NWSS_nv_554_Treatment plant_90_raw wastewater                                       0.243687
# NWSS_wi_231_Treatment plant_raw wastewater                                          0.464501
# NWSS_wv_2553_Treatment plant_raw wastewater                                         0.357797
# NWSS_wv_2558_Treatment plant_raw wastewater                                         0.374541
# NWSS_wv_2562_Treatment plant_raw wastewater                                         0.407408
# confirmed_cases                                                                     0.399310
# CTK_pos                                                                             0.472218
# COVID-NET                                                                           0.360861
# ER_adm                                                                              0.640702
# New_COVID_7DayADM_rate                                                              0.164847
#
#                                                NWSS_mi_800_Treatment plant_raw wastewater  \
# NWSS_mi_757_Treatment plant_post grit removal                                    0.641268
# NWSS_mi_761_Treatment plant_post grit removal                                    0.589465
# NWSS_mi_762_Treatment plant_post grit removal                                    0.628532
# NWSS_mi_799_Treatment plant_post grit removal                                    0.582934
# NWSS_mi_800_Treatment plant_raw wastewater                                       1.000000
# NWSS_nv_554_Treatment plant_90_raw wastewater                                    0.169924
# NWSS_wi_231_Treatment plant_raw wastewater                                       0.430154
# NWSS_wv_2553_Treatment plant_raw wastewater                                      0.440962
# NWSS_wv_2558_Treatment plant_raw wastewater                                      0.282776
# NWSS_wv_2562_Treatment plant_raw wastewater                                      0.407309
# confirmed_cases                                                                  0.624839
# CTK_pos                                                                          0.213103
# COVID-NET                                                                        0.436939
# ER_adm                                                                           0.485459
# New_COVID_7DayADM_rate                                                           0.311603
#
#                                                NWSS_nv_554_Treatment plant_90_raw wastewater  \
# NWSS_mi_757_Treatment plant_post grit removal                                       0.043701
# NWSS_mi_761_Treatment plant_post grit removal                                       0.215758
# NWSS_mi_762_Treatment plant_post grit removal                                       0.175970
# NWSS_mi_799_Treatment plant_post grit removal                                       0.243687
# NWSS_mi_800_Treatment plant_raw wastewater                                          0.169924
# NWSS_nv_554_Treatment plant_90_raw wastewater                                       1.000000
# NWSS_wi_231_Treatment plant_raw wastewater                                          0.115520
# NWSS_wv_2553_Treatment plant_raw wastewater                                         0.557433
# NWSS_wv_2558_Treatment plant_raw wastewater                                         0.436694
# NWSS_wv_2562_Treatment plant_raw wastewater                                         0.226343
# confirmed_cases                                                                    -0.059163
# CTK_pos                                                                             0.036766
# COVID-NET                                                                          -0.155856
# ER_adm                                                                              0.234593
# New_COVID_7DayADM_rate                                                             -0.209225
#
#                                                NWSS_wi_231_Treatment plant_raw wastewater  \
# NWSS_mi_757_Treatment plant_post grit removal                                    0.611308
# NWSS_mi_761_Treatment plant_post grit removal                                    0.499189
# NWSS_mi_762_Treatment plant_post grit removal                                    0.528293
# NWSS_mi_799_Treatment plant_post grit removal                                    0.464501
# NWSS_mi_800_Treatment plant_raw wastewater                                       0.430154
# NWSS_nv_554_Treatment plant_90_raw wastewater                                    0.115520
# NWSS_wi_231_Treatment plant_raw wastewater                                       1.000000
# NWSS_wv_2553_Treatment plant_raw wastewater                                      0.387951
# NWSS_wv_2558_Treatment plant_raw wastewater                                      0.390218
# NWSS_wv_2562_Treatment plant_raw wastewater                                      0.385524
# confirmed_cases                                                                       NaN
# CTK_pos                                                                          0.503102
# COVID-NET                                                                        0.586006
# ER_adm                                                                           0.689067
# New_COVID_7DayADM_rate                                                           0.417990
#
#                                                NWSS_wv_2553_Treatment plant_raw wastewater  \
# NWSS_mi_757_Treatment plant_post grit removal                                     0.402240
# NWSS_mi_761_Treatment plant_post grit removal                                     0.483040
# NWSS_mi_762_Treatment plant_post grit removal                                     0.313517
# NWSS_mi_799_Treatment plant_post grit removal                                     0.357797
# NWSS_mi_800_Treatment plant_raw wastewater                                        0.440962
# NWSS_nv_554_Treatment plant_90_raw wastewater                                     0.557433
# NWSS_wi_231_Treatment plant_raw wastewater                                        0.387951
# NWSS_wv_2553_Treatment plant_raw wastewater                                       1.000000
# NWSS_wv_2558_Treatment plant_raw wastewater                                       0.567445
# NWSS_wv_2562_Treatment plant_raw wastewater                                       0.523963
# confirmed_cases                                                                   0.643873
# CTK_pos                                                                           0.121303
# COVID-NET                                                                         0.285138
# ER_adm                                                                            0.380690
# New_COVID_7DayADM_rate                                                            0.265424
#
#                                                NWSS_wv_2558_Treatment plant_raw wastewater  \
# NWSS_mi_757_Treatment plant_post grit removal                                     0.214886
# NWSS_mi_761_Treatment plant_post grit removal                                     0.367278
# NWSS_mi_762_Treatment plant_post grit removal                                     0.227151
# NWSS_mi_799_Treatment plant_post grit removal                                     0.374541
# NWSS_mi_800_Treatment plant_raw wastewater                                        0.282776
# NWSS_nv_554_Treatment plant_90_raw wastewater                                     0.436694
# NWSS_wi_231_Treatment plant_raw wastewater                                        0.390218
# NWSS_wv_2553_Treatment plant_raw wastewater                                       0.567445
# NWSS_wv_2558_Treatment plant_raw wastewater                                       1.000000
# NWSS_wv_2562_Treatment plant_raw wastewater                                       0.515543
# confirmed_cases                                                                   0.551791
# CTK_pos                                                                           0.302218
# COVID-NET                                                                        -0.055090
# ER_adm                                                                            0.514904
# New_COVID_7DayADM_rate                                                           -0.124172
#
#                                                NWSS_wv_2562_Treatment plant_raw wastewater  \
# NWSS_mi_757_Treatment plant_post grit removal                                     0.455062
# NWSS_mi_761_Treatment plant_post grit removal                                     0.414128
# NWSS_mi_762_Treatment plant_post grit removal                                     0.315206
# NWSS_mi_799_Treatment plant_post grit removal                                     0.407408
# NWSS_mi_800_Treatment plant_raw wastewater                                        0.407309
# NWSS_nv_554_Treatment plant_90_raw wastewater                                     0.226343
# NWSS_wi_231_Treatment plant_raw wastewater                                        0.385524
# NWSS_wv_2553_Treatment plant_raw wastewater                                       0.523963
# NWSS_wv_2558_Treatment plant_raw wastewater                                       0.515543
# NWSS_wv_2562_Treatment plant_raw wastewater                                       1.000000
# confirmed_cases                                                                   0.534740
# CTK_pos                                                                           0.976776
# COVID-NET                                                                         0.167921
# ER_adm                                                                            0.804401
# New_COVID_7DayADM_rate                                                            1.000000
#
#                                                confirmed_cases   CTK_pos  \
# NWSS_mi_757_Treatment plant_post grit removal         0.350145  0.421533
# NWSS_mi_761_Treatment plant_post grit removal         0.847974  0.428220
# NWSS_mi_762_Treatment plant_post grit removal         0.411237  0.335618
# NWSS_mi_799_Treatment plant_post grit removal         0.399310  0.472218
# NWSS_mi_800_Treatment plant_raw wastewater            0.624839  0.213103
# NWSS_nv_554_Treatment plant_90_raw wastewater        -0.059163  0.036766
# NWSS_wi_231_Treatment plant_raw wastewater                 NaN  0.503102
# NWSS_wv_2553_Treatment plant_raw wastewater           0.643873  0.121303
# NWSS_wv_2558_Treatment plant_raw wastewater           0.551791  0.302218
# NWSS_wv_2562_Treatment plant_raw wastewater           0.534740  0.976776
# confirmed_cases                                       1.000000       NaN
# CTK_pos                                                    NaN  1.000000
# COVID-NET                                                  NaN  0.388138
# ER_adm                                                     NaN  0.765373
# New_COVID_7DayADM_rate                                     NaN  0.552086
#
#                                                COVID-NET    ER_adm  \
# NWSS_mi_757_Treatment plant_post grit removal   0.595346  0.690394
# NWSS_mi_761_Treatment plant_post grit removal   0.515036  0.606376
# NWSS_mi_762_Treatment plant_post grit removal   0.482945  0.589005
# NWSS_mi_799_Treatment plant_post grit removal   0.360861  0.640702
# NWSS_mi_800_Treatment plant_raw wastewater      0.436939  0.485459
# NWSS_nv_554_Treatment plant_90_raw wastewater  -0.155856  0.234593
# NWSS_wi_231_Treatment plant_raw wastewater      0.586006  0.689067
# NWSS_wv_2553_Treatment plant_raw wastewater     0.285138  0.380690
# NWSS_wv_2558_Treatment plant_raw wastewater    -0.055090  0.514904
# NWSS_wv_2562_Treatment plant_raw wastewater     0.167921  0.804401
# confirmed_cases                                      NaN       NaN
# CTK_pos                                         0.388138  0.765373
# COVID-NET                                       1.000000  0.867170
# ER_adm                                          0.867170  1.000000
# New_COVID_7DayADM_rate                          0.946696  0.935944
#
#                                                New_COVID_7DayADM_rate
# NWSS_mi_757_Treatment plant_post grit removal                0.460653
# NWSS_mi_761_Treatment plant_post grit removal                0.433305
# NWSS_mi_762_Treatment plant_post grit removal                0.286518
# NWSS_mi_799_Treatment plant_post grit removal                0.164847
# NWSS_mi_800_Treatment plant_raw wastewater                   0.311603
# NWSS_nv_554_Treatment plant_90_raw wastewater               -0.209225
# NWSS_wi_231_Treatment plant_raw wastewater                   0.417990
# NWSS_wv_2553_Treatment plant_raw wastewater                  0.265424
# NWSS_wv_2558_Treatment plant_raw wastewater                 -0.124172
# NWSS_wv_2562_Treatment plant_raw wastewater                  1.000000
# confirmed_cases                                                   NaN
# CTK_pos                                                      0.552086
# COVID-NET                                                    0.946696
# ER_adm                                                       0.935944
# New_COVID_7DayADM_rate                                       1.000000

# %%
agg_data.to_csv('C:/Users/matth/OneDrive/Documents/Projects/Science/Sentinel/COVID tracker/aggregated_covid_data.csv',sep='|')
